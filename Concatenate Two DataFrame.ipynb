# %%
import pandas as pd

# %%
df = pd.read_csv('ITIL raw-clean.csv')
df_2 = pd.read_csv('ITIL-2021.csv')

# %%
df.head(10000)
# Out:
#            Issue ID                                        Issue Title  \
# 0     ITIL-15192-21                    Got locked out from the laptop.
# 1     ITIL-15189-21  Printer HP pagewide T4 CCR Fluid container is ...
# 2     ITIL-15187-21                               Share Sanny calandar
# 3     ITIL-15186-21                          unable to connect printer
# 4     ITIL-15184-21  Unable to connect to hotspot internet and unab...
# ...             ...                                                ...
# 8534   ITIL-6801-19                  Approver Section does not appear
# 8535   ITIL-6798-19                         Staff claim "fail to post"
# 8536   ITIL-6795-19  Access to add new item & edit in Extranet Vend...
# 8537   ITIL-6785-19                              Request access folder
# 8538   ITIL-6781-19          Meeting room recurrence booking in Macnet
#
#      Issue Category Infra Category SAP Category  \
# 0          IT Infra        User ID          NaN
# ...

# %%
list(df['Issue ID'])
# Out:
# ['ITIL-15192-21',
#  'ITIL-15189-21',
#  'ITIL-15187-21',
#  'ITIL-15186-21',
#  'ITIL-15184-21',
#  'ITIL-15181-21',
#  'ITIL-15180-21',
#  'ITIL-15178-21',
#  'ITIL-15177-21',
#  'ITIL-15176-21',
#  'ITIL-15175-21',
#  'ITIL-15173-21',
#  'ITIL-15171-21',
#  'ITIL-15170-21',
#  'ITIL-15169-21',
#  'ITIL-15167-21',
#  'ITIL-15166-21',
#  'ITIL-15165-21',
#  'ITIL-15162-21',
#  'ITIL-15158-21',
#  'ITIL-15156-21',
#  'ITIL-15152-21',
#  'ITIL-15151-21',
#  'ITIL-15149-21',
#  'ITIL-15147-21',
#  'ITIL-15146-21',
#  'ITIL-15135-21',
#  'ITIL-15131-21',
#  'ITIL-15130-21',
#  'ITIL-15125-21',
#  'ITIL-15124-21',
#  'ITIL-15122-21',
#  'ITIL-15121-21',
#  'ITIL-15119-21',
#  'ITIL-15116-21',
#  'ITIL-15115-21',
#  'ITIL-15113-21',
#  'ITIL-15111-21',
#  'ITIL-15110-21',
#  'ITIL-15109-21',
#  'ITIL-15107-21',
#  'ITIL-15102-21',
#  'ITIL-15098-21',
#  'ITIL-15097-21',
#  'ITIL-15093-21',
#  'ITIL-15089-21',
#  'ITIL-15087-21',
#  'ITIL-15084-21',
#  'ITIL-15083-21',
#  'ITIL-15081-21',
# ...

# %%
df_2.head(10000)
# Out:
#            Issue ID                                        Issue Title  \
# 0     ITIL-12897-21            To install Ni-Soft e-clipse (V2.72.11)
# 1     ITIL-12898-21                            cannot download ot form
# 2     ITIL-12899-21                                       SAP & Nisoft
# 3     ITIL-12900-21             RENEW CONTRACT 1 JAN UNTIL 31 DEC 2021
# 4     ITIL-12901-21                         Ot form cannot been submit
# ...             ...                                                ...
# 2579  ITIL-15464-21  Meeting Room Online Booking not seen in Macnet...
# 2580  ITIL-15465-21                                          ID locked
# 2581  ITIL-15466-21       To correct Agreement List Plant&Company Code
# 2582  ITIL-15467-21  Parent Account Cannot Be Billed - 3000057 & 30...
# 2583  ITIL-15468-21                  Installation Adobe Acrobat Pro DC
#
#      Issue Category Infra Category    SAP Category SP Category  \
# ...

# %%
df_2['Created']
# Out:
# 0         1/1/2021 8:22
# 1         1/1/2021 8:32
# 2         1/1/2021 9:37
# 3         1/1/2021 9:49
# 4        1/1/2021 10:12
#              ...
# 2579     6/12/2021 9:12
# 2580     6/12/2021 9:24
# 2581    6/12/2021 10:11
# 2582    6/12/2021 10:52
# 2583    6/12/2021 11:11
# Name: Created, Length: 2584, dtype: object

# %%
df_2['Created'] = pd.to_datetime(df_2['Created'], format='%d/%m/%Y %H:%M')
df['Created'] = pd.to_datetime(df['Created'], format='%d/%m/%Y %H:%M')

# %%
df_2.dtypes
# Out:
# Issue ID                                        object
# Issue Title                                     object
# Issue Category                                  object
# Infra Category                                  object
# SAP Category                                    object
# SP Category                                     object
# Sub-category                                    object
# Site Type                                       object
# Issue Status                                    object
# Requested By                                    object
# Created By                                      object
# txtRequesterDiv                                 object
# txtRequesterLoc                                 object
# Priority                                        object
# Created                                 datetime64[ns]
# Resolved Date                                   object
# Due Date                                        object
# ...

# %%
df_2['Created']
# Out:
# 0      2021-01-01 08:22:00
# 1      2021-01-01 08:32:00
# 2      2021-01-01 09:37:00
# 3      2021-01-01 09:49:00
# 4      2021-01-01 10:12:00
#                ...
# 2579   2021-12-06 09:12:00
# 2580   2021-12-06 09:24:00
# 2581   2021-12-06 10:11:00
# 2582   2021-12-06 10:52:00
# 2583   2021-12-06 11:11:00
# Name: Created, Length: 2584, dtype: datetime64[ns]

# %%
mask = (df['Created'] > '31.12.2018') & (df['Created'] <= '31.12.2020')

# %%
df = df.loc[mask]

# %%
df['Created']
# Out:
# 2319   2020-12-30 17:14:00
# 2320   2020-12-30 13:04:00
# 2321   2020-12-30 11:17:00
# 2322   2020-12-30 10:43:00
# 2323   2020-12-30 09:39:00
#                ...
# 8534   2019-01-03 11:43:00
# 8535   2019-01-03 10:19:00
# 8536   2019-01-03 08:44:00
# 8537   2019-01-02 14:34:00
# 8538   2019-01-02 11:41:00
# Name: Created, Length: 6220, dtype: datetime64[ns]

# %%
df.head(10000)
# Out:
#            Issue ID                                        Issue Title  \
# 2319  ITIL-12883-20                                        Wifi Access
# 2320  ITIL-12881-20                                          Setup VPN
# 2321  ITIL-12880-20                                Ghost Mouse Request
# 2322  ITIL-12879-20                                        Install SVG
# 2323  ITIL-12877-20                                         PTW NISOFT
# ...             ...                                                ...
# 8534   ITIL-6801-19                  Approver Section does not appear
# 8535   ITIL-6798-19                         Staff claim "fail to post"
# 8536   ITIL-6795-19  Access to add new item & edit in Extranet Vend...
# 8537   ITIL-6785-19                              Request access folder
# 8538   ITIL-6781-19          Meeting room recurrence booking in Macnet
#
#      Issue Category Infra Category SAP Category  \
# 2319       IT Infra        Network          NaN
# ...

# %%
df_2.head(10000)
# Out:
#            Issue ID                                        Issue Title  \
# 0     ITIL-12897-21            To install Ni-Soft e-clipse (V2.72.11)
# 1     ITIL-12898-21                            cannot download ot form
# 2     ITIL-12899-21                                       SAP & Nisoft
# 3     ITIL-12900-21             RENEW CONTRACT 1 JAN UNTIL 31 DEC 2021
# 4     ITIL-12901-21                         Ot form cannot been submit
# ...             ...                                                ...
# 2579  ITIL-15464-21  Meeting Room Online Booking not seen in Macnet...
# 2580  ITIL-15465-21                                          ID locked
# 2581  ITIL-15466-21       To correct Agreement List Plant&Company Code
# 2582  ITIL-15467-21  Parent Account Cannot Be Billed - 3000057 & 30...
# 2583  ITIL-15468-21                  Installation Adobe Acrobat Pro DC
#
#      Issue Category Infra Category    SAP Category SP Category  \
# ...

# %%
df_final = pd.concat([df, df_2], ignore_index=True)

# %%
df_final.head(10000)
# Out:
#            Issue ID                                        Issue Title  \
# 0     ITIL-12883-20                                        Wifi Access
# 1     ITIL-12881-20                                          Setup VPN
# 2     ITIL-12880-20                                Ghost Mouse Request
# 3     ITIL-12879-20                                        Install SVG
# 4     ITIL-12877-20                                         PTW NISOFT
# ...             ...                                                ...
# 8799  ITIL-15464-21  Meeting Room Online Booking not seen in Macnet...
# 8800  ITIL-15465-21                                          ID locked
# 8801  ITIL-15466-21       To correct Agreement List Plant&Company Code
# 8802  ITIL-15467-21  Parent Account Cannot Be Billed - 3000057 & 30...
# 8803  ITIL-15468-21                  Installation Adobe Acrobat Pro DC
#
#      Issue Category Infra Category    SAP Category SP Category  \
# ...

# %%
df_final.to_csv('ITIL NOV2021.csv', index=False, header=True)
