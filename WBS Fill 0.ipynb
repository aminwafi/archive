# %%
import pandas as pd

# %%
df = pd.read_csv("WBS - Environmental Services.csv")

# %%
df.head()
# Out:
#               Product             Sub-Product Ease of Implementation   \
# 0  Monitoring System           Cyber Security                    Hard
# 1                 NaN  Performance Networking                    Hard
# 2                 NaN                     RnD                    Hard
# 3                 NaN           Asset Tagging                    Hard
# 4                 NaN       Vehicle Profiling                    Hard
#
#   Digital Impact  People  Process  Technology  Experience  Drive Decision  \
# 0  Modernisation     1.0      1.0         1.0         NaN             NaN
# 1  Modernisation     NaN      NaN         1.0         NaN             1.0
# 2  Modernisation     NaN      1.0         1.0         1.0             NaN
# 3  Modernisation     NaN      1.0         1.0         NaN             NaN
# 4  Modernisation     NaN      1.0         1.0         NaN             1.0
#
#    Process Efficiency  Scalability  Year of Delivery
# ...

# %%
df['People'] = df['People'].fillna(0)
df['Process'] = df['Process'].fillna(0)
df['Technology'] = df['Technology'].fillna(0)
df['Experience'] = df['Experience'].fillna(0)
df['Drive Decision'] = df['Drive Decision'].fillna(0)
df['Process Efficiency'] = df['Process Efficiency'].fillna(0)
df['Scalability'] = df['Scalability'].fillna(0)

# %%
df.head()
# Out:
#               Product             Sub-Product Ease of Implementation   \
# 0  Monitoring System           Cyber Security                    Hard
# 1                 NaN  Performance Networking                    Hard
# 2                 NaN                     RnD                    Hard
# 3                 NaN           Asset Tagging                    Hard
# 4                 NaN       Vehicle Profiling                    Hard
#
#   Digital Impact  People  Process  Technology  Experience  Drive Decision  \
# 0  Modernisation     1.0      1.0         1.0         0.0             0.0
# 1  Modernisation     0.0      0.0         1.0         0.0             1.0
# 2  Modernisation     0.0      1.0         1.0         1.0             0.0
# 3  Modernisation     0.0      1.0         1.0         0.0             0.0
# 4  Modernisation     0.0      1.0         1.0         0.0             1.0
#
#    Process Efficiency  Scalability  Year of Delivery
# ...

# %%
df.to_csv('E')
