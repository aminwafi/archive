# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ITIL 22-10-2021.csv')

# %%
df.head()
# Out:
#         Issue ID                    Issue Title Issue Category Infra Category  \
# 0  ITIL-15064-21              VPN not available       IT Infra         Server
# 1  ITIL-15059-21      TEAMS can't perform right       IT Infra    Laptop / PC
# 2  ITIL-15057-21        Cannot login to outlook       IT Infra          Email
# 3  ITIL-15056-21                Printer & Email       IT Infra        Printer
# 4  ITIL-15053-21  Reference Account Locked out.       IT Infra    Laptop / PC
#
#   SAP Category SP Category  Sub-category         Site Type Issue Status  \
# 0          NaN         NaN       Server     IT Infra - PPP         Open
# 1          NaN         NaN  Laptop / PC   IT Infra - TGBIN         Open
# 2          NaN         NaN        Email      IT Infra - HQ         Open
# 3          NaN         NaN      Printer   IT Infra - TGBIN       Closed
# 4          NaN         NaN  Laptop / PC     IT Infra - PPP       Closed
#
# ...

# %%
df["Site Category"][df['Site Type'].str.contains("IT Infra", na=False)] = "IT Infra"
# Out:
# <ipython-input-8-08ed839d34bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Site Category"][df['Site Type'].str.contains("IT Infra", na=False)] = "IT Infra"

# %%
df.head()
# Out:
#         Issue ID                    Issue Title Issue Category Infra Category  \
# 0  ITIL-15064-21              VPN not available       IT Infra         Server
# 1  ITIL-15059-21      TEAMS can't perform right       IT Infra    Laptop / PC
# 2  ITIL-15057-21        Cannot login to outlook       IT Infra          Email
# 3  ITIL-15056-21                Printer & Email       IT Infra        Printer
# 4  ITIL-15053-21  Reference Account Locked out.       IT Infra    Laptop / PC
#
#   SAP Category SP Category  Sub-category         Site Type Issue Status  \
# 0          NaN         NaN       Server     IT Infra - PPP         Open
# 1          NaN         NaN  Laptop / PC   IT Infra - TGBIN         Open
# 2          NaN         NaN        Email      IT Infra - HQ         Open
# 3          NaN         NaN      Printer   IT Infra - TGBIN       Closed
# 4          NaN         NaN  Laptop / PC     IT Infra - PPP       Closed
#
# ...
