# %%
import pandas as pd

# %%
df = pd.read_csv('Backup Data.csv')
df.head()
# Out:
#     Status Objects Processed  Backup Type         Start Time  Data Size (GB)  \
# 0  Success                 0  Incremental     6/3/2021 19:30            0.00
# 1  Success                 0  Incremental     6/6/2021 20:09            0.00
# 2  Success                 0  Incremental  6/16/2021 7:30 PM            0.00
# 3  Success                 0  Incremental  6/17/2021 7:30 PM            0.00
# 4  Warning            1 of 1  Incremental  6/20/2021 8:05 PM         1184.99
#
#    Transferred (GB)  Total Backup Size (GB)                  Job Name  \
# 0              0.00                 1330.24  TN91 - Malakoff_Others03
# 1              0.00                 1338.05  TN91 - Malakoff_Others03
# 2              0.00                 1345.72  TN91 - Malakoff_Others03
# 3              0.00                 1350.50  TN91 - Malakoff_Others03
# 4             40.16                 1335.82  TN91 - Malakoff_Others03
#
#   Job Location
# 0          VPC
# 1          VPC
# 2          VPC
# ...

# %%
df['Start Time'] = pd.to_datetime(df['Start Time']).dt.strftime('%m/%d/%Y')

# %%
df['Start Time'] = pd.to_datetime(df['Start Time'])

# %%
df.dtypes
# Out:
# Status                            object
# Objects Processed                 object
# Backup Type                       object
# Start Time                datetime64[ns]
# Data Size (GB)                   float64
# Transferred (GB)                 float64
# Total Backup Size (GB)           float64
# Job Name                          object
# Job Location                      object
# dtype: object

# %%
df.head(2000)
# Out:
#        Status Objects Processed  Backup Type Start Time  Data Size (GB)  \
# 0     Success                 0  Incremental 2021-06-03        0.000000
# 1     Success                 0  Incremental 2021-06-06        0.000000
# 2     Success                 0  Incremental 2021-06-16        0.000000
# 3     Success                 0  Incremental 2021-06-17        0.000000
# 4     Warning            1 of 1  Incremental 2021-06-20     1184.990000
# ...       ...               ...          ...        ...             ...
# 1995  Success                 3  Incremental 2021-09-14     2594.999039
# 1996  Success                 3  Incremental 2021-09-15     2594.999039
# 1997  Success                 3  Incremental 2021-09-16     2594.999039
# 1998  Success                 3  Incremental 2021-09-17     2594.999039
# 1999  Success                 3  Incremental 2021-09-18     2594.999039
#
#       Transferred (GB)  Total Backup Size (GB)                  Job Name  \
# ...

# %%
df.to_csv('Backup Data Cleansed.csv', index = False, header = True)
